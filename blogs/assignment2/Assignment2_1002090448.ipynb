# %%
import string
import pandas as pd
import numpy as np
import re
from tqdm import tqdm

# %% [markdown]
# # Loading and preprocessing data

# %% [markdown]
# ##### We will first load data and do preprocessing steps by removinf unwanted words and stopwords

# %%
df = pd.read_csv("rt_reviews.csv", encoding='cp1252')

# %%
df.head()
# Out:
#   Freshness                                             Review
# 0     fresh   Manakamana doesn't answer any questions, yet ...
# 1     fresh   Wilfully offensive and powered by a chest-thu...
# 2    rotten   It would be difficult to imagine material mor...
# 3    rotten   Despite the gusto its star brings to the role...
# 4    rotten   If there was a good idea at the core of this ...

# %%
stop_words = ["a", "an", "the", "and", "or", "but", "is", "am", "are", "was", "were", "be", "being", "been", "have", "has", "had", "do", "does", "did", "will", "would", "shall", "should", "can", "could", "may", "might", "must"]

# %%
review=[]
for i in df.Review:
    a=[]
    
    for j in i.split():
        word = j.lower()
        word = re.sub(r'[^\w\d\s_]+', '', word)
        if word not in stop_words:
            a.append(word)
    s = " ".join(a)
    s=s.strip()
    review.append(s)

# %%
df.Review = review
df.Review.head()
# Out:
# 0    manakamana doesnt answer any questions yet mak...
# 1    wilfully offensive powered by chestthumping ma...
# 2    it difficult to imagine material more wrong fo...
# 3    despite gusto its star brings to role its hard...
# 4    if there good idea at core of this film its bu...
# Name: Review, dtype: object

# %% [markdown]
# ## Dividing dataset into 3 categories

# %% [markdown]
# ###### Here we divide dataset into training, testing and development sets

# %%
len_of_dataset = len(df)
train_size = int(len_of_dataset*0.6)
validation_size = int(len_of_dataset*0.2)
test_size = int(len_of_dataset*0.2)

# %%
train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]
validation_data = df[train_size+test_size:]

# %% [markdown]
# #### Creating count for every word in training dataset review

# %%
word_count={}
for sentence in train_data.Review:
    for word in sentence.split():
        if word in word_count:
            word_count[word]+=1
        else:
            word_count[word]=1
words = [words for words,values in word_count.items() if values>=5]

# %% [markdown]
# ###### Mapping word to a number and reverse

# %%
index_to_word = {}
for n,i in enumerate(words):
    index_to_word[n] = i

word_to_index= {}
for n,word in index_to_word.items():
    word_to_index[word] = n

# %%
index_to_word
# Out:
# {0: 'doesnt',
#  1: 'answer',
#  2: 'any',
#  3: 'questions',
#  4: 'yet',
#  5: 'makes',
#  6: 'its',
#  7: 'point',
#  8: 'like',
#  9: 'rest',
#  10: 'of',
#  11: 'our',
#  12: 'planet',
#  13: 'picturesque',
#  14: 'far',
#  15: 'from',
#  16: 'kingdom',
#  17: 'wilfully',
#  18: 'offensive',
#  19: 'powered',
#  20: 'by',
#  21: 'chestthumping',
#  22: 'machismo',
#  23: 'good',
#  24: 'clean',
#  25: 'fun',
#  26: 'it',
#  27: 'difficult',
#  28: 'to',
#  29: 'imagine',
#  30: 'material',
#  31: 'more',
#  32: 'wrong',
#  33: 'for',
#  34: 'spade',
#  35: 'than',
#  36: 'lost',
#  37: 'found',
#  38: 'despite',
#  39: 'gusto',
#  40: 'star',
#  41: 'brings',
#  42: 'role',
#  43: 'hard',
#  44: 'ride',
#  45: 'shotgun',
#  46: 'on',
#  47: 'hectors',
#  48: 'voyage',
#  49: 'discovery',
#  50: 'if',
#  51: 'there',
#  52: 'idea',
#  53: 'at',
#  54: 'core',
#  55: 'this',
#  56: 'film',
#  57: 'buried',
#  58: 'in',
#  59: 'unsightly',
#  60: 'pile',
#  61: 'flatulence',
#  62: 'jokes',
#  63: 'bad',
#  64: 'puns',
#  65: 'ridiculous',
#  66: 'serial',
#  67: 'plot',
#  68: 'gleeson',
#  69: 'goes',
#  70: 'hallmark',
#  71: 'channel',
#  72: 'route',
#  73: 'damaging',
#  74: 'intermittently',
#  75: 'curious',
#  76: 'entry',
#  77: 'time',
#  78: 'travel',
#  79: 'subgenre',
#  80: 'height',
#  81: 'satire',
#  82: '1976',
#  83: 'dark',
#  84: 'as',
#  85: 'hell',
#  86: 'patently',
#  87: 'absurd',
#  88: 'surely',
#  89: 'nowhere',
#  90: 'close',
#  91: 'objective',
#  92: 'reality',
#  93: 'surpassed',
#  94: 'somewhere',
#  95: 'jerry',
#  96: 'springer',
#  97: 'era',
#  98: 'everyone',
#  99: 'comedian',
#  100: 'deserves',
#  101: 'better',
#  102: 'movie',
#  103: 'actor',
#  104: 'encourages',
#  105: 'grumpy',
#  106: 'christians',
#  107: 'embrace',
#  108: 'season',
#  109: 'slight',
#  110: 'contained',
#  111: 'ineffably',
#  112: 'soulful',
#  113: 'bells',
#  114: 'debut',
#  115: 'feature',
#  116: 'addresses',
#  117: 'subject',
#  118: 'with',
#  119: 'both',
#  120: 'humor',
#  121: 'intelligence',
#  122: 'approaching',
#  123: 'issue',
#  124: 'performance',
#  125: 'enhancement',
#  126: 'every',
#  127: 'conceivable',
#  128: 'angle',
#  129: 'except',
#  130: 'shamelessly',
#  131: 'irresistibly',
#  132: 'zingy',
#  133: 'music',
#  134: 'score',
#  135: 'director',
#  136: 'halloween',
#  137: 'achieves',
#  138: 'considerable',
#  139: 'power',
#  140: 'almost',
#  141: 'entirely',
#  142: 'through',
#  143: 'visual',
#  144: 'means',
#  145: 'not',
#  146: 'one',
#  147: 'uninitiated',
#  148: 'also',
#  149: 'people',
#  150: 'who',
#  151: 'action',
#  152: 'thrills',
#  153: 'son',
#  154: 'saul',
#  155: 'employs',
#  156: 'formal',
#  157: 'mechanics',
#  158: 'filmmaking',
#  159: 'turn',
#  160: 'back',
#  161: 'around',
#  162: 'themselves',
#  163: 'doing',
#  164: 'what',
#  165: 'cinema',
#  166: 'best',
#  167: 'hands',
#  168: 'great',
#  169: 'filmmakers',
#  170: 'showing',
#  171: 'telling',
#  172: 'isnt',
#  173: 'thrilling',
#  174: 'fox',
#  175: 'cant',
#  176: 'act',
#  177: 'filthy',
#  178: 'funny',
#  179: 'hiddleston',
#  180: 'swinton',
#  181: 'lovely',
#  182: 'watch',
#  183: 'they',
#  184: 'need',
#  185: 'chew',
#  186: 'yossi',
#  187: 'stronger',
#  188: 'predecessor',
#  189: 'deeply',
#  190: 'felt',
#  191: 'less',
#  192: 'reliant',
#  193: 'conventions',
#  194: 'i',
#  195: 'feel',
#  196: 'sparkle',
#  197: 'baby',
#  198: 'just',
#  199: 'puked',
#  200: 'dust',
#  201: 'all',
#  202: 'over',
#  203: 'my',
#  204: 'head',
#  205: 'long',
#  206: 'unfocused',
#  207: 'kubo',
#  208: 'two',
#  209: 'strings',
#  210: 'immersive',
#  211: 'pulled',
#  212: 'knights',
#  213: 'direction',
#  214: 'we',
#  215: 'become',
#  216: 'part',
#  217: 'his',
#  218: 'studios',
#  219: 'technical',
#  220: 'wizardry',
#  221: 'easy',
#  222: 'enjoy',
#  223: 'youre',
#  224: 'susceptible',
#  225: 'sort',
#  226: 'thing',
#  227: 'leaves',
#  228: 'you',
#  229: 'nothing',
#  230: 'think',
#  231: 'about',
#  232: 'opportunities',
#  233: 'brooks',
#  234: 'missed',
#  235: 'make',
#  236: 'something',
#  237: 'worthwhile',
#  238: 'out',
#  239: 'extraordinary',
#  240: 'blast',
#  241: 'past',
#  242: 'xmen',
#  243: 'first',
#  244: 'class',
#  245: 'go',
#  246: 'down',
#  247: 'decades',
#  248: 'superhero',
#  249: 'movies',
#  250: 'mostly',
#  251: 'lightweight',
#  252: 'most',
#  253: 'interesting',
#  254: 'jamie',
#  255: 'foxx',
#  256: 'electro',
#  257: 'villain',
#  258: 'embodies',
#  259: 'black',
#  260: 'rage',
#  261: 'malcolm',
#  262: 'x',
#  263: 'mutant',
#  264: 'drawn',
#  265: 'per',
#  266: 'disclaimer',
#  267: 'period',
#  268: 'accounts',
#  269: 'strange',
#  270: 'phenomena',
#  271: 'psychotic',
#  272: 'breaks',
#  273: 'among',
#  274: 'impeccably',
#  275: 'crafted',
#  276: 'historically',
#  277: 'accurate',
#  278: 'creepshow',
#  279: 'wears',
#  280: 'deepdive',
#  281: 'research',
#  282: 'tattered',
#  283: 'sleeves',
#  284: 'hones',
#  285: 'dramatic',
#  286: 'elements',
#  287: 'emotional',
#  288: 'effect',
#  289: 'rather',
#  290: 'fall',
#  291: 'slasher',
#  292: 'template',
#  293: 'moretz',
#  294: 'her',
#  295: 'agame',
#  296: 'seemed',
#  297: 'decent',
#  298: 'fourth',
#  299: 'final',
#  300: 'stroll',
#  301: 'american',
#  302: 'pie',
#  303: 'gutter',
#  304: 'swamped',
#  305: 'reason',
#  306: 'why',
#  307: 'these',
#  308: 'actors',
#  309: 'havent',
#  310: 'worked',
#  311: 'much',
#  312: 'between',
#  313: 'sequels',
#  314: 'simply',
#  315: 'arent',
#  316: 'special',
#  317: 'even',
#  318: 'that',
#  319: 'theyre',
#  320: 'free',
#  321: 'birds',
#  322: 'unappealingly',
#  323: 'staged',
#  324: 'paced',
#  325: 'uneven',
#  326: 'sluggishness',
#  327: 'begs',
#  328: 'question',
#  329: 'since',
#  330: 'things',
#  331: 'always',
#  332: 'seem',
#  333: 'happening',
#  334: 'so',
#  335: 'crushingly',
#  336: 'dull',
#  337: 'joyless',
#  338: 'misanthropic',
#  339: '105',
#  340: 'minutes',
#  341: 'worth',
#  342: 'comedy',
#  343: 'rates',
#  344: 'coen',
#  345: 'brothers',
#  346: 'their',
#  347: 'worst',
#  348: 'how',
#  349: 'take',
#  350: 'such',
#  351: 'marvelous',
#  352: 'into',
#  353: 'mystery',
#  354: 'critic',
#  355: 'directed',
#  356: 'john',
#  357: 'glen',
#  358: 'follows',
#  359: 'numbers',
#  360: 'plodding',
#  361: 'unimaginative',
#  362: 'set',
#  363: 'piece',
#  364: 'next',
#  365: 'purely',
#  366: 'visceral',
#  367: 'generating',
#  368: 'adrenaline',
#  369: 'alarm',
#  370: 'tears',
#  371: 'berg',
#  372: 'manages',
#  373: 'avoid',
#  374: 'highminded',
#  375: 'seriousness',
#  376: 'while',
#  377: 'still',
#  378: 'respecting',
#  379: 'peppermint',
#  380: 'least',
#  381: 'trash',
#  382: 'decides',
#  383: 'exercise',
#  384: 'shallowness',
#  385: 'want',
#  386: 'high',
#  387: 'body',
#  388: 'count',
#  389: 'step',
#  390: 'right',
#  391: 'brains',
#  392: 'behind',
#  393: 'sorely',
#  394: 'hidden',
#  395: 'agenda',
#  396: 'eventually',
#  397: 'surfaces',
#  398: 'strain',
#  399: 'credibility',
#  400: 'fosters',
#  401: 'ability',
#  402: 'reign',
#  403: 'improbable',
#  404: 'allows',
#  405: 'flight',
#  406: 'deliver',
#  407: 'requisite',
#  408: 'romantic',
#  409: 'new',
#  410: 'offer',
#  411: 'rise',
#  412: 'awkwafina',
#  413: 'riffs',
#  414: 'wealth',
#  415: 'gap',
#  416: 'race',
#  417: 'relies',
#  418: 'stereotypes',
#  419: 'estevez',
#  420: 'well',
#  421: 'having',
#  422: 'your',
#  423: 'heart',
#  424: 'place',
#  425: 'no',
#  426: 'excuse',
#  427: 'insipid',
#  428: 'ineptitude',
#  429: 'ralston',
#  430: 'seems',
#  431: 'love',
#  432: 'living',
#  433: 'life',
#  434: 'ragged',
#  435: 'edge',
#  436: 'disaster',
#  437: 'boyles',
#  438: 'rides',
#  439: 'same',
#  440: 'narrow',
#  441: 'breathtaking',
#  442: 'works',
#  443: 'fine',
#  444: 'standalone',
#  445: 'entertainment',
#  446: 'irreparable',
#  447: 'harm',
#  448: 'series',
#  449: 'whole',
#  450: 'hangover',
#  451: 'ii',
#  452: 'notably',
#  453: 'justify',
#  454: 'effort',
#  455: 'spent',
#  456: 'add',
#  457: 'nearly',
#  458: 'identical',
#  459: 'episodes',
#  460: 'original',
#  461: 'multiplex',
#  462: 'amy',
#  463: 'sedaris',
#  464: 'suits',
#  465: 'up',
#  466: 'everyones',
#  467: 'favorite',
#  468: 'school',
#  469: 'student',
#  470: 'quite',
#  471: 'version',
#  472: 'cult',
#  473: 'tv',
#  474: 'see',
#  475: 'unadorned',
#  476: 'faces',
#  477: 'staring',
#  478: 'camera',
#  479: 'afternoon',
#  480: 'shadows',
#  481: 'moving',
#  482: 'across',
#  483: 'large',
#  484: 'building',
#  485: 'forlorn',
#  486: 'images',
#  487: 'abandoned',
#  488: 'amusement',
#  489: 'park',
#  490: 'misty',
#  491: 'magical',
#  492: 'quiet',
#  493: 'swamp',
#  494: 'throughout',
#  495: 'documentary',
#  496: 'gorgeous',
#  497: 'teenagers',
#  498: 'goofy',
#  499: 'smiles',
#  500: 'ache',
#  501: 'beautifully',
#  502: 'shot',
#  503: 'aggressively',
#  504: 'menacing',
#  505: 'turns',
#  506: 'sumptuous',
#  507: 'disturbing',
#  508: 'concept',
#  509: 'cooler',
#  510: 'execution',
#  511: 'gyllenhaal',
#  512: 'ledger',
#  513: 'embody',
#  514: 'old',
#  515: 'willie',
#  516: 'song',
#  517: 'taught',
#  518: 'us',
#  519: 'cowboys',
#  520: 'aint',
#  521: 'harder',
#  522: 'hold',
#  523: 'unsubtle',
#  524: 'times',
#  525: 'backing',
#  526: 'trying',
#  527: 'say',
#  528: 'says',
#  529: 'extensively',
#  530: 'choreographed',
#  531: 'fight',
#  532: 'sequence',
#  533: 'which',
#  534: 'mortal',
#  535: 'blows',
#  536: 'delivered',
#  537: 'often',
#  538: 'little',
#  539: 'lasting',
#  540: 'impact',
#  541: 'brawl',
#  542: 'becomes',
#  543: 'bergmans',
#  544: 'undisputed',
#  545: 'masterpieces',
#  546: 'seminal',
#  547: 'work',
#  548: 'raising',
#  549: 'complex',
#  550: 'identity',
#  551: 'roleplaying',
#  552: 'possibly',
#  553: 'thus',
#  554: 'deliberately',
#  555: 'encouraging',
#  556: 'ambivalence',
#  557: 'ambiguity',
#  558: 'somehow',
#  559: 'revolutionary',
#  560: 'empowering',
#  561: 'message',
#  562: 'never',
#  563: 'got',
#  564: 'dunn',
#  565: 'sexually',
#  566: 'psychologically',
#  567: 'arrested',
#  568: 'pathology',
#  569: 'blocks',
#  570: 'coming',
#  571: 'frothy',
#  572: 'girlpower',
#  573: 'manifesto',
#  574: 'briskly',
#  575: 'sharply',
#  576: 'written',
#  577: 'infectiously',
#  578: 'entertaining',
#  579: 'deficiencies',
#  580: 'insignificant',
#  581: 'lightly',
#  582: 'chipped',
#  583: 'disappointing',
#  584: 'rosemarys',
#  585: 'stoop',
#  586: 'desperate',
#  587: 'pyrotechnics',
#  588: 'nudity',
#  589: 'put',
#  590: 'together',
#  591: 'too',
#  592: 'choppily',
#  593: 'appreciate',
#  594: 'athleticism',
#  595: 'parkour',
#  596: 'confirms',
#  597: 'perception',
#  598: 'only',
#  599: 'losers',
#  600: 'attend',
#  601: 'highschool',
#  602: 'reunions',
#  603: 'younger',
#  604: 'truly',
#  605: 'wanted',
#  606: 'some',
#  607: 'fantasies',
#  608: 'big',
#  609: 'screen',
#  610: 'prime',
#  611: 'dullest',
#  612: 'way',
#  613: 'he',
#  614: 'couldve',
#  615: 'achieved',
#  616: 'goal',
#  617: 'expect',
#  618: 'embellishment',
#  619: 'horror',
#  620: 'thriller',
#  621: 'claims',
#  622: 'based',
#  623: 'true',
#  624: 'story',
#  625: 'actual',
#  626: 'events',
#  627: 'however',
#  628: 'sell',
#  629: 'merely',
#  630: 'viewer',
#  631: 'delight',
#  632: 'hilarity',
#  633: 'generated',
#  634: 'mr',
#  635: 'cable',
#  636: 'guy',
#  637: 'breaking',
#  638: 'wind',
#  639: 'vomiting',
#  640: 'producing',
#  641: 'various',
#  642: 'noises',
#  643: 'etc',
#  644: 'own',
#  645: 'enough',
#  646: 'said',
#  647: 'sweet',
#  648: 'charming',
#  649: 'theres',
#  650: 'loss',
#  651: 'beloved',
#  652: 'leading',
#  653: 'man',
#  654: 'lends',
#  655: 'picture',
#  656: 'extra',
#  657: 'unexpected',
#  658: 'pathos',
#  659: 'perhaps',
#  660: 'adequate',
#  661: 'animated',
#  662: 'children',
#  663: 'thor',
#  664: 'others',
#  665: 'played',
#  666: 'piglets',
#  667: 'arena',
#  668: 'comic',
#  669: 'book',
#  670: 'superheroes',
#  671: 'desolate',
#  672: 'short',
#  673: 'fresh',
#  674: 'ideas',
#  675: 'thanks',
#  676: 'strong',
#  677: 'performances',
#  678: 'script',
#  679: 'provides',
#  680: 'depth',
#  681: 'render',
#  682: 'characters',
#  683: 'collection',
#  684: 'eccentricities',
#  685: 'thought',
#  686: 'oscarwinning',
#  687: '2004',
#  688: 'drama',
#  689: 'crash',
#  690: 'heavyhanded',
#  691: 'wait',
#  692: 'until',
#  693: 'crossing',
#  694: 'gatlifs',
#  695: 'view',
#  696: 'flamenco',
#  697: 'excruciatingly',
#  698: 'trite',
#  699: 'mountain',
#  700: 'crap',
#  701: 'when',
#  702: 'remembers',
#  703: 'supposed',
#  704: 'hokum',
#  705: 'wit',
#  706: 'leave',
#  707: 'attenborough',
#  708: 'wilson',
#  709: 'forget',
#  710: 'rash',
#  711: 'putative',
#  712: 'improvements',
#  713: 'family',
#  714: 'fare',
#  715: 'sex',
#  716: 'scenes',
#  717: 'pretty',
#  718: 'hot',
#  719: 'though',
#  720: 'diminished',
#  721: 'limited',
#  722: 'perfectly',
#  723: 'enjoyable',
#  724: 'forgettable',
#  725: 'general',
#  726: 'playful',
#  727: 'tone',
#  728: 'helps',
#  729: 'deal',
#  730: 'cinematography',
#  731: 'editing',
#  732: 'appealingly',
#  733: 'glossy',
#  734: 'smooth',
#  735: 'spielbergs',
#  736: 'neither',
#  737: 'popcorn',
#  738: 'flick',
#  739: 'nor',
#  740: 'paul',
#  741: 'subversion',
#  742: 'uneasily',
#  743: 'fanboy',
#  744: 'demographic',
#  745: 'political',
#  746: 'gripping',
#  747: 'focuses',
#  748: 'innocent',
#  749: 'whose',
#  750: 'lives',
#  751: 'destroyed',
#  752: 'either',
#  753: 'terrorists',
#  754: 'administration',
#  755: 'feeling',
#  756: 'saw',
#  757: 'bottom',
#  758: 'dirty',
#  759: 'glass',
#  760: 'experience',
#  761: 'precision',
#  762: 'duplicates',
#  763: 'sensation',
#  764: 'success',
#  765: 'reconstituted',
#  766: 'blend',
#  767: 'ghostbusters',
#  768: 'meets',
#  769: 'men',
#  770: 'pinch',
#  771: 'xfiles',
#  772: 'problems',
#  773: 'dont',
#  774: 'amount',
#  775: 'hill',
#  776: 'beans',
#  777: 'stalins',
#  778: 'real',
#  779: 'experiencing',
#  780: 'them',
#  781: 'world',
#  782: 'cash',
#  783: 'grab',
#  784: 'painting',
#  785: 'perpetrator',
#  786: 'saviour',
#  787: 'exploited',
#  788: 'victims',
#  789: 'fringes',
#  790: 'society',
#  791: 'models',
#  792: 'figures',
#  793: 'inspiration',
#  794: 'mainstream',
#  795: 'uncritical',
#  796: 'audiences',
#  797: 'mother',
#  798: 'courage',
#  799: 'full',
#  800: 'review',
#  801: 'spanish',
#  802: 'let',
#  803: 'live',
#  804: 'happily',
#  805: 'ever',
#  806: 'after',
#  807: 'come',
#  808: 'sides',
#  809: 'heavy',
#  810: 'lifting',
#  811: 'falls',
#  812: 'watson',
#  813: 'moments',
#  814: 'where',
#  815: 'she',
#  816: 'wipe',
#  817: 'familys',
#  818: 'memories',
#  819: 'protect',
#  820: 'task',
#  821: 'navelgazing',
#  822: 'listless',
#  823: 'mary',
#  824: 'magdalene',
#  825: 'nevertheless',
#  826: 'affecting',
#  827: 'contemplative',
#  828: 'hagiography',
#  829: 'biblical',
#  830: 'figure',
#  831: 'inclined',
#  832: 'towards',
#  833: 'arthouse',
#  834: 'aesthetic',
#  835: 'anything',
#  836: 'faithbased',
#  837: 'lawrence',
#  838: 'reunites',
#  839: 'hunger',
#  840: 'games',
#  841: 'sadistic',
#  842: 'sexedup',
#  843: 'russian',
#  844: 'spy',
#  845: 'saga',
#  846: 'made',
#  847: '50',
#  848: 'years',
#  849: 'ago',
#  850: 'blackandwhite',
#  851: 'french',
#  852: 'classic',
#  853: 'grabs',
#  854: 'throat',
#  855: 'particularly',
#  856: 'seyfried',
#  857: 'redgrave',
#  858: 'help',
#  859: 'spirit',
#  860: 'contagious',
#  861: 'nicely',
#  862: 'gory',
#  863: 'feels',
#  864: 'uninspired',
#  865: 'handsomely',
#  866: 'photographed',
#  867: 'consequence',
#  868: 'damon',
#  869: 'superbly',
#  870: 'silly',
#  871: 'beautiful',
#  872: 'mind',
#  873: 'films',
#  874: 'greatest',
#  875: 'talent',
#  876: 'water',
#  877: 'cross',
#  878: 'tipping',
#  879: 'hurts',
#  880: 'dogged',
#  881: 'insistence',
#  882: 'turning',
#  883: 'another',
#  884: 'seemingly',
#  885: 'endless',
#  886: 'middlebrow',
#  887: 'meditations',
#  888: 'travails',
#  889: 'middleclass',
#  890: 'krampus',
#  891: 'toothless',
#  892: 'several',
#  893: 'levels',
#  894: 'very',
#  895: 'wellworn',
#  896: 'clichï½ï½s',
#  897: 'sf',
#  898: 'completely',
#  899: 'transparent',
#  900: 'production',
#  901: 'design',
#  902: 'seriousminded',
#  903: 'celebration',
#  904: 'youll',
#  905: 'hear',
#  906: 'phrase',
#  907: 'doors',
#  908: 'again',
#  909: 'clear',
#  910: 'guys',
#  911: 'making',
#  912: 'translates',
#  913: 'onto',
#  914: 'marketed',
#  915: 'historical',
#  916: 'fiction',
#  917: 'king',
#  918: 'arthur',
#  919: 'actually',
#  920: 'octane',
#  921: 'fantasy',
#  922: 'showcases',
#  923: 'excalibur',
#  924: 'guiding',
#  925: 'destiny',
#  926: 'chemistry',
#  927: 'leads',
#  928: 'breezy',
#  929: 'aging',
#  930: 'wistful',
#  931: 'reminiscences',
#  932: 'itself',
#  933: 'lifetimes',
#  934: 'pleasures',
#  935: 'operate',
#  936: 'genius',
#  937: 'level',
#  938: 'given',
#  939: 'field',
#  940: 'mean',
#  941: 'cost',
#  942: 'purgatory',
#  943: 'bobby',
#  944: 'fischer',
#  945: 'inhabited',
#  946: 'essential',
#  947: 'maintaining',
#  948: 'powerful',
#  949: 'atmospherics',
#  950: 'superb',
#  951: 'cast',
#  952: 'includes',
#  953: 'nicole',
#  954: 'kidman',
#  955: 'surgeons',
#  956: 'unsuspecting',
#  957: 'wife',
#  958: 'grounds',
#  959: 'spectacle',
#  960: 'pushing',
#  961: 'beyond',
#  962: 'twohour',
#  963: 'ejaculation',
#  964: 'yearning',
#  965: 'innocence',
#  966: 'uniformly',
#  967: 'excellent',
#  968: 'truth',
#  969: 'plain',
#  970: 'done',
#  971: 'rote',
#  972: 'introductory',
#  973: 'potions',
#  974: 'year',
#  975: 'capturing',
#  976: 'particular',
#  977: 'age',
#  978: 'group',
#  979: 'those',
#  980: 'late',
#  981: '20s',
#  982: 'early',
#  983: '30s',
#  984: 'entering',
#  985: 'adulthood',
#  986: 'certain',
#  987: 'reluctance',
#  988: 'trepidation',
#  989: 'ballards',
#  990: 'exist',
#  991: 'distract',
#  992: 'conventional',
#  993: 'failings',
#  994: 'craftsmanship',
#  995: 'bring',
#  996: 'spouse',
#  997: 'vicariously',
#  998: 'hickenlooper',
#  999: 'unsure',
#  ...}

# %%
word_to_index
# Out:
# {'doesnt': 0,
#  'answer': 1,
#  'any': 2,
#  'questions': 3,
#  'yet': 4,
#  'makes': 5,
#  'its': 6,
#  'point': 7,
#  'like': 8,
#  'rest': 9,
#  'of': 10,
#  'our': 11,
#  'planet': 12,
#  'picturesque': 13,
#  'far': 14,
#  'from': 15,
#  'kingdom': 16,
#  'wilfully': 17,
#  'offensive': 18,
#  'powered': 19,
#  'by': 20,
#  'chestthumping': 21,
#  'machismo': 22,
#  'good': 23,
#  'clean': 24,
#  'fun': 25,
#  'it': 26,
#  'difficult': 27,
#  'to': 28,
#  'imagine': 29,
#  'material': 30,
#  'more': 31,
#  'wrong': 32,
#  'for': 33,
#  'spade': 34,
#  'than': 35,
#  'lost': 36,
#  'found': 37,
#  'despite': 38,
#  'gusto': 39,
#  'star': 40,
#  'brings': 41,
#  'role': 42,
#  'hard': 43,
#  'ride': 44,
#  'shotgun': 45,
#  'on': 46,
#  'hectors': 47,
#  'voyage': 48,
#  'discovery': 49,
#  'if': 50,
#  'there': 51,
#  'idea': 52,
#  'at': 53,
#  'core': 54,
#  'this': 55,
#  'film': 56,
#  'buried': 57,
#  'in': 58,
#  'unsightly': 59,
#  'pile': 60,
#  'flatulence': 61,
#  'jokes': 62,
#  'bad': 63,
#  'puns': 64,
#  'ridiculous': 65,
#  'serial': 66,
#  'plot': 67,
#  'gleeson': 68,
#  'goes': 69,
#  'hallmark': 70,
#  'channel': 71,
#  'route': 72,
#  'damaging': 73,
#  'intermittently': 74,
#  'curious': 75,
#  'entry': 76,
#  'time': 77,
#  'travel': 78,
#  'subgenre': 79,
#  'height': 80,
#  'satire': 81,
#  '1976': 82,
#  'dark': 83,
#  'as': 84,
#  'hell': 85,
#  'patently': 86,
#  'absurd': 87,
#  'surely': 88,
#  'nowhere': 89,
#  'close': 90,
#  'objective': 91,
#  'reality': 92,
#  'surpassed': 93,
#  'somewhere': 94,
#  'jerry': 95,
#  'springer': 96,
#  'era': 97,
#  'everyone': 98,
#  'comedian': 99,
#  'deserves': 100,
#  'better': 101,
#  'movie': 102,
#  'actor': 103,
#  'encourages': 104,
#  'grumpy': 105,
#  'christians': 106,
#  'embrace': 107,
#  'season': 108,
#  'slight': 109,
#  'contained': 110,
#  'ineffably': 111,
#  'soulful': 112,
#  'bells': 113,
#  'debut': 114,
#  'feature': 115,
#  'addresses': 116,
#  'subject': 117,
#  'with': 118,
#  'both': 119,
#  'humor': 120,
#  'intelligence': 121,
#  'approaching': 122,
#  'issue': 123,
#  'performance': 124,
#  'enhancement': 125,
#  'every': 126,
#  'conceivable': 127,
#  'angle': 128,
#  'except': 129,
#  'shamelessly': 130,
#  'irresistibly': 131,
#  'zingy': 132,
#  'music': 133,
#  'score': 134,
#  'director': 135,
#  'halloween': 136,
#  'achieves': 137,
#  'considerable': 138,
#  'power': 139,
#  'almost': 140,
#  'entirely': 141,
#  'through': 142,
#  'visual': 143,
#  'means': 144,
#  'not': 145,
#  'one': 146,
#  'uninitiated': 147,
#  'also': 148,
#  'people': 149,
#  'who': 150,
#  'action': 151,
#  'thrills': 152,
#  'son': 153,
#  'saul': 154,
#  'employs': 155,
#  'formal': 156,
#  'mechanics': 157,
#  'filmmaking': 158,
#  'turn': 159,
#  'back': 160,
#  'around': 161,
#  'themselves': 162,
#  'doing': 163,
#  'what': 164,
#  'cinema': 165,
#  'best': 166,
#  'hands': 167,
#  'great': 168,
#  'filmmakers': 169,
#  'showing': 170,
#  'telling': 171,
#  'isnt': 172,
#  'thrilling': 173,
#  'fox': 174,
#  'cant': 175,
#  'act': 176,
#  'filthy': 177,
#  'funny': 178,
#  'hiddleston': 179,
#  'swinton': 180,
#  'lovely': 181,
#  'watch': 182,
#  'they': 183,
#  'need': 184,
#  'chew': 185,
#  'yossi': 186,
#  'stronger': 187,
#  'predecessor': 188,
#  'deeply': 189,
#  'felt': 190,
#  'less': 191,
#  'reliant': 192,
#  'conventions': 193,
#  'i': 194,
#  'feel': 195,
#  'sparkle': 196,
#  'baby': 197,
#  'just': 198,
#  'puked': 199,
#  'dust': 200,
#  'all': 201,
#  'over': 202,
#  'my': 203,
#  'head': 204,
#  'long': 205,
#  'unfocused': 206,
#  'kubo': 207,
#  'two': 208,
#  'strings': 209,
#  'immersive': 210,
#  'pulled': 211,
#  'knights': 212,
#  'direction': 213,
#  'we': 214,
#  'become': 215,
#  'part': 216,
#  'his': 217,
#  'studios': 218,
#  'technical': 219,
#  'wizardry': 220,
#  'easy': 221,
#  'enjoy': 222,
#  'youre': 223,
#  'susceptible': 224,
#  'sort': 225,
#  'thing': 226,
#  'leaves': 227,
#  'you': 228,
#  'nothing': 229,
#  'think': 230,
#  'about': 231,
#  'opportunities': 232,
#  'brooks': 233,
#  'missed': 234,
#  'make': 235,
#  'something': 236,
#  'worthwhile': 237,
#  'out': 238,
#  'extraordinary': 239,
#  'blast': 240,
#  'past': 241,
#  'xmen': 242,
#  'first': 243,
#  'class': 244,
#  'go': 245,
#  'down': 246,
#  'decades': 247,
#  'superhero': 248,
#  'movies': 249,
#  'mostly': 250,
#  'lightweight': 251,
#  'most': 252,
#  'interesting': 253,
#  'jamie': 254,
#  'foxx': 255,
#  'electro': 256,
#  'villain': 257,
#  'embodies': 258,
#  'black': 259,
#  'rage': 260,
#  'malcolm': 261,
#  'x': 262,
#  'mutant': 263,
#  'drawn': 264,
#  'per': 265,
#  'disclaimer': 266,
#  'period': 267,
#  'accounts': 268,
#  'strange': 269,
#  'phenomena': 270,
#  'psychotic': 271,
#  'breaks': 272,
#  'among': 273,
#  'impeccably': 274,
#  'crafted': 275,
#  'historically': 276,
#  'accurate': 277,
#  'creepshow': 278,
#  'wears': 279,
#  'deepdive': 280,
#  'research': 281,
#  'tattered': 282,
#  'sleeves': 283,
#  'hones': 284,
#  'dramatic': 285,
#  'elements': 286,
#  'emotional': 287,
#  'effect': 288,
#  'rather': 289,
#  'fall': 290,
#  'slasher': 291,
#  'template': 292,
#  'moretz': 293,
#  'her': 294,
#  'agame': 295,
#  'seemed': 296,
#  'decent': 297,
#  'fourth': 298,
#  'final': 299,
#  'stroll': 300,
#  'american': 301,
#  'pie': 302,
#  'gutter': 303,
#  'swamped': 304,
#  'reason': 305,
#  'why': 306,
#  'these': 307,
#  'actors': 308,
#  'havent': 309,
#  'worked': 310,
#  'much': 311,
#  'between': 312,
#  'sequels': 313,
#  'simply': 314,
#  'arent': 315,
#  'special': 316,
#  'even': 317,
#  'that': 318,
#  'theyre': 319,
#  'free': 320,
#  'birds': 321,
#  'unappealingly': 322,
#  'staged': 323,
#  'paced': 324,
#  'uneven': 325,
#  'sluggishness': 326,
#  'begs': 327,
#  'question': 328,
#  'since': 329,
#  'things': 330,
#  'always': 331,
#  'seem': 332,
#  'happening': 333,
#  'so': 334,
#  'crushingly': 335,
#  'dull': 336,
#  'joyless': 337,
#  'misanthropic': 338,
#  '105': 339,
#  'minutes': 340,
#  'worth': 341,
#  'comedy': 342,
#  'rates': 343,
#  'coen': 344,
#  'brothers': 345,
#  'their': 346,
#  'worst': 347,
#  'how': 348,
#  'take': 349,
#  'such': 350,
#  'marvelous': 351,
#  'into': 352,
#  'mystery': 353,
#  'critic': 354,
#  'directed': 355,
#  'john': 356,
#  'glen': 357,
#  'follows': 358,
#  'numbers': 359,
#  'plodding': 360,
#  'unimaginative': 361,
#  'set': 362,
#  'piece': 363,
#  'next': 364,
#  'purely': 365,
#  'visceral': 366,
#  'generating': 367,
#  'adrenaline': 368,
#  'alarm': 369,
#  'tears': 370,
#  'berg': 371,
#  'manages': 372,
#  'avoid': 373,
#  'highminded': 374,
#  'seriousness': 375,
#  'while': 376,
#  'still': 377,
#  'respecting': 378,
#  'peppermint': 379,
#  'least': 380,
#  'trash': 381,
#  'decides': 382,
#  'exercise': 383,
#  'shallowness': 384,
#  'want': 385,
#  'high': 386,
#  'body': 387,
#  'count': 388,
#  'step': 389,
#  'right': 390,
#  'brains': 391,
#  'behind': 392,
#  'sorely': 393,
#  'hidden': 394,
#  'agenda': 395,
#  'eventually': 396,
#  'surfaces': 397,
#  'strain': 398,
#  'credibility': 399,
#  'fosters': 400,
#  'ability': 401,
#  'reign': 402,
#  'improbable': 403,
#  'allows': 404,
#  'flight': 405,
#  'deliver': 406,
#  'requisite': 407,
#  'romantic': 408,
#  'new': 409,
#  'offer': 410,
#  'rise': 411,
#  'awkwafina': 412,
#  'riffs': 413,
#  'wealth': 414,
#  'gap': 415,
#  'race': 416,
#  'relies': 417,
#  'stereotypes': 418,
#  'estevez': 419,
#  'well': 420,
#  'having': 421,
#  'your': 422,
#  'heart': 423,
#  'place': 424,
#  'no': 425,
#  'excuse': 426,
#  'insipid': 427,
#  'ineptitude': 428,
#  'ralston': 429,
#  'seems': 430,
#  'love': 431,
#  'living': 432,
#  'life': 433,
#  'ragged': 434,
#  'edge': 435,
#  'disaster': 436,
#  'boyles': 437,
#  'rides': 438,
#  'same': 439,
#  'narrow': 440,
#  'breathtaking': 441,
#  'works': 442,
#  'fine': 443,
#  'standalone': 444,
#  'entertainment': 445,
#  'irreparable': 446,
#  'harm': 447,
#  'series': 448,
#  'whole': 449,
#  'hangover': 450,
#  'ii': 451,
#  'notably': 452,
#  'justify': 453,
#  'effort': 454,
#  'spent': 455,
#  'add': 456,
#  'nearly': 457,
#  'identical': 458,
#  'episodes': 459,
#  'original': 460,
#  'multiplex': 461,
#  'amy': 462,
#  'sedaris': 463,
#  'suits': 464,
#  'up': 465,
#  'everyones': 466,
#  'favorite': 467,
#  'school': 468,
#  'student': 469,
#  'quite': 470,
#  'version': 471,
#  'cult': 472,
#  'tv': 473,
#  'see': 474,
#  'unadorned': 475,
#  'faces': 476,
#  'staring': 477,
#  'camera': 478,
#  'afternoon': 479,
#  'shadows': 480,
#  'moving': 481,
#  'across': 482,
#  'large': 483,
#  'building': 484,
#  'forlorn': 485,
#  'images': 486,
#  'abandoned': 487,
#  'amusement': 488,
#  'park': 489,
#  'misty': 490,
#  'magical': 491,
#  'quiet': 492,
#  'swamp': 493,
#  'throughout': 494,
#  'documentary': 495,
#  'gorgeous': 496,
#  'teenagers': 497,
#  'goofy': 498,
#  'smiles': 499,
#  'ache': 500,
#  'beautifully': 501,
#  'shot': 502,
#  'aggressively': 503,
#  'menacing': 504,
#  'turns': 505,
#  'sumptuous': 506,
#  'disturbing': 507,
#  'concept': 508,
#  'cooler': 509,
#  'execution': 510,
#  'gyllenhaal': 511,
#  'ledger': 512,
#  'embody': 513,
#  'old': 514,
#  'willie': 515,
#  'song': 516,
#  'taught': 517,
#  'us': 518,
#  'cowboys': 519,
#  'aint': 520,
#  'harder': 521,
#  'hold': 522,
#  'unsubtle': 523,
#  'times': 524,
#  'backing': 525,
#  'trying': 526,
#  'say': 527,
#  'says': 528,
#  'extensively': 529,
#  'choreographed': 530,
#  'fight': 531,
#  'sequence': 532,
#  'which': 533,
#  'mortal': 534,
#  'blows': 535,
#  'delivered': 536,
#  'often': 537,
#  'little': 538,
#  'lasting': 539,
#  'impact': 540,
#  'brawl': 541,
#  'becomes': 542,
#  'bergmans': 543,
#  'undisputed': 544,
#  'masterpieces': 545,
#  'seminal': 546,
#  'work': 547,
#  'raising': 548,
#  'complex': 549,
#  'identity': 550,
#  'roleplaying': 551,
#  'possibly': 552,
#  'thus': 553,
#  'deliberately': 554,
#  'encouraging': 555,
#  'ambivalence': 556,
#  'ambiguity': 557,
#  'somehow': 558,
#  'revolutionary': 559,
#  'empowering': 560,
#  'message': 561,
#  'never': 562,
#  'got': 563,
#  'dunn': 564,
#  'sexually': 565,
#  'psychologically': 566,
#  'arrested': 567,
#  'pathology': 568,
#  'blocks': 569,
#  'coming': 570,
#  'frothy': 571,
#  'girlpower': 572,
#  'manifesto': 573,
#  'briskly': 574,
#  'sharply': 575,
#  'written': 576,
#  'infectiously': 577,
#  'entertaining': 578,
#  'deficiencies': 579,
#  'insignificant': 580,
#  'lightly': 581,
#  'chipped': 582,
#  'disappointing': 583,
#  'rosemarys': 584,
#  'stoop': 585,
#  'desperate': 586,
#  'pyrotechnics': 587,
#  'nudity': 588,
#  'put': 589,
#  'together': 590,
#  'too': 591,
#  'choppily': 592,
#  'appreciate': 593,
#  'athleticism': 594,
#  'parkour': 595,
#  'confirms': 596,
#  'perception': 597,
#  'only': 598,
#  'losers': 599,
#  'attend': 600,
#  'highschool': 601,
#  'reunions': 602,
#  'younger': 603,
#  'truly': 604,
#  'wanted': 605,
#  'some': 606,
#  'fantasies': 607,
#  'big': 608,
#  'screen': 609,
#  'prime': 610,
#  'dullest': 611,
#  'way': 612,
#  'he': 613,
#  'couldve': 614,
#  'achieved': 615,
#  'goal': 616,
#  'expect': 617,
#  'embellishment': 618,
#  'horror': 619,
#  'thriller': 620,
#  'claims': 621,
#  'based': 622,
#  'true': 623,
#  'story': 624,
#  'actual': 625,
#  'events': 626,
#  'however': 627,
#  'sell': 628,
#  'merely': 629,
#  'viewer': 630,
#  'delight': 631,
#  'hilarity': 632,
#  'generated': 633,
#  'mr': 634,
#  'cable': 635,
#  'guy': 636,
#  'breaking': 637,
#  'wind': 638,
#  'vomiting': 639,
#  'producing': 640,
#  'various': 641,
#  'noises': 642,
#  'etc': 643,
#  'own': 644,
#  'enough': 645,
#  'said': 646,
#  'sweet': 647,
#  'charming': 648,
#  'theres': 649,
#  'loss': 650,
#  'beloved': 651,
#  'leading': 652,
#  'man': 653,
#  'lends': 654,
#  'picture': 655,
#  'extra': 656,
#  'unexpected': 657,
#  'pathos': 658,
#  'perhaps': 659,
#  'adequate': 660,
#  'animated': 661,
#  'children': 662,
#  'thor': 663,
#  'others': 664,
#  'played': 665,
#  'piglets': 666,
#  'arena': 667,
#  'comic': 668,
#  'book': 669,
#  'superheroes': 670,
#  'desolate': 671,
#  'short': 672,
#  'fresh': 673,
#  'ideas': 674,
#  'thanks': 675,
#  'strong': 676,
#  'performances': 677,
#  'script': 678,
#  'provides': 679,
#  'depth': 680,
#  'render': 681,
#  'characters': 682,
#  'collection': 683,
#  'eccentricities': 684,
#  'thought': 685,
#  'oscarwinning': 686,
#  '2004': 687,
#  'drama': 688,
#  'crash': 689,
#  'heavyhanded': 690,
#  'wait': 691,
#  'until': 692,
#  'crossing': 693,
#  'gatlifs': 694,
#  'view': 695,
#  'flamenco': 696,
#  'excruciatingly': 697,
#  'trite': 698,
#  'mountain': 699,
#  'crap': 700,
#  'when': 701,
#  'remembers': 702,
#  'supposed': 703,
#  'hokum': 704,
#  'wit': 705,
#  'leave': 706,
#  'attenborough': 707,
#  'wilson': 708,
#  'forget': 709,
#  'rash': 710,
#  'putative': 711,
#  'improvements': 712,
#  'family': 713,
#  'fare': 714,
#  'sex': 715,
#  'scenes': 716,
#  'pretty': 717,
#  'hot': 718,
#  'though': 719,
#  'diminished': 720,
#  'limited': 721,
#  'perfectly': 722,
#  'enjoyable': 723,
#  'forgettable': 724,
#  'general': 725,
#  'playful': 726,
#  'tone': 727,
#  'helps': 728,
#  'deal': 729,
#  'cinematography': 730,
#  'editing': 731,
#  'appealingly': 732,
#  'glossy': 733,
#  'smooth': 734,
#  'spielbergs': 735,
#  'neither': 736,
#  'popcorn': 737,
#  'flick': 738,
#  'nor': 739,
#  'paul': 740,
#  'subversion': 741,
#  'uneasily': 742,
#  'fanboy': 743,
#  'demographic': 744,
#  'political': 745,
#  'gripping': 746,
#  'focuses': 747,
#  'innocent': 748,
#  'whose': 749,
#  'lives': 750,
#  'destroyed': 751,
#  'either': 752,
#  'terrorists': 753,
#  'administration': 754,
#  'feeling': 755,
#  'saw': 756,
#  'bottom': 757,
#  'dirty': 758,
#  'glass': 759,
#  'experience': 760,
#  'precision': 761,
#  'duplicates': 762,
#  'sensation': 763,
#  'success': 764,
#  'reconstituted': 765,
#  'blend': 766,
#  'ghostbusters': 767,
#  'meets': 768,
#  'men': 769,
#  'pinch': 770,
#  'xfiles': 771,
#  'problems': 772,
#  'dont': 773,
#  'amount': 774,
#  'hill': 775,
#  'beans': 776,
#  'stalins': 777,
#  'real': 778,
#  'experiencing': 779,
#  'them': 780,
#  'world': 781,
#  'cash': 782,
#  'grab': 783,
#  'painting': 784,
#  'perpetrator': 785,
#  'saviour': 786,
#  'exploited': 787,
#  'victims': 788,
#  'fringes': 789,
#  'society': 790,
#  'models': 791,
#  'figures': 792,
#  'inspiration': 793,
#  'mainstream': 794,
#  'uncritical': 795,
#  'audiences': 796,
#  'mother': 797,
#  'courage': 798,
#  'full': 799,
#  'review': 800,
#  'spanish': 801,
#  'let': 802,
#  'live': 803,
#  'happily': 804,
#  'ever': 805,
#  'after': 806,
#  'come': 807,
#  'sides': 808,
#  'heavy': 809,
#  'lifting': 810,
#  'falls': 811,
#  'watson': 812,
#  'moments': 813,
#  'where': 814,
#  'she': 815,
#  'wipe': 816,
#  'familys': 817,
#  'memories': 818,
#  'protect': 819,
#  'task': 820,
#  'navelgazing': 821,
#  'listless': 822,
#  'mary': 823,
#  'magdalene': 824,
#  'nevertheless': 825,
#  'affecting': 826,
#  'contemplative': 827,
#  'hagiography': 828,
#  'biblical': 829,
#  'figure': 830,
#  'inclined': 831,
#  'towards': 832,
#  'arthouse': 833,
#  'aesthetic': 834,
#  'anything': 835,
#  'faithbased': 836,
#  'lawrence': 837,
#  'reunites': 838,
#  'hunger': 839,
#  'games': 840,
#  'sadistic': 841,
#  'sexedup': 842,
#  'russian': 843,
#  'spy': 844,
#  'saga': 845,
#  'made': 846,
#  '50': 847,
#  'years': 848,
#  'ago': 849,
#  'blackandwhite': 850,
#  'french': 851,
#  'classic': 852,
#  'grabs': 853,
#  'throat': 854,
#  'particularly': 855,
#  'seyfried': 856,
#  'redgrave': 857,
#  'help': 858,
#  'spirit': 859,
#  'contagious': 860,
#  'nicely': 861,
#  'gory': 862,
#  'feels': 863,
#  'uninspired': 864,
#  'handsomely': 865,
#  'photographed': 866,
#  'consequence': 867,
#  'damon': 868,
#  'superbly': 869,
#  'silly': 870,
#  'beautiful': 871,
#  'mind': 872,
#  'films': 873,
#  'greatest': 874,
#  'talent': 875,
#  'water': 876,
#  'cross': 877,
#  'tipping': 878,
#  'hurts': 879,
#  'dogged': 880,
#  'insistence': 881,
#  'turning': 882,
#  'another': 883,
#  'seemingly': 884,
#  'endless': 885,
#  'middlebrow': 886,
#  'meditations': 887,
#  'travails': 888,
#  'middleclass': 889,
#  'krampus': 890,
#  'toothless': 891,
#  'several': 892,
#  'levels': 893,
#  'very': 894,
#  'wellworn': 895,
#  'clichï½ï½s': 896,
#  'sf': 897,
#  'completely': 898,
#  'transparent': 899,
#  'production': 900,
#  'design': 901,
#  'seriousminded': 902,
#  'celebration': 903,
#  'youll': 904,
#  'hear': 905,
#  'phrase': 906,
#  'doors': 907,
#  'again': 908,
#  'clear': 909,
#  'guys': 910,
#  'making': 911,
#  'translates': 912,
#  'onto': 913,
#  'marketed': 914,
#  'historical': 915,
#  'fiction': 916,
#  'king': 917,
#  'arthur': 918,
#  'actually': 919,
#  'octane': 920,
#  'fantasy': 921,
#  'showcases': 922,
#  'excalibur': 923,
#  'guiding': 924,
#  'destiny': 925,
#  'chemistry': 926,
#  'leads': 927,
#  'breezy': 928,
#  'aging': 929,
#  'wistful': 930,
#  'reminiscences': 931,
#  'itself': 932,
#  'lifetimes': 933,
#  'pleasures': 934,
#  'operate': 935,
#  'genius': 936,
#  'level': 937,
#  'given': 938,
#  'field': 939,
#  'mean': 940,
#  'cost': 941,
#  'purgatory': 942,
#  'bobby': 943,
#  'fischer': 944,
#  'inhabited': 945,
#  'essential': 946,
#  'maintaining': 947,
#  'powerful': 948,
#  'atmospherics': 949,
#  'superb': 950,
#  'cast': 951,
#  'includes': 952,
#  'nicole': 953,
#  'kidman': 954,
#  'surgeons': 955,
#  'unsuspecting': 956,
#  'wife': 957,
#  'grounds': 958,
#  'spectacle': 959,
#  'pushing': 960,
#  'beyond': 961,
#  'twohour': 962,
#  'ejaculation': 963,
#  'yearning': 964,
#  'innocence': 965,
#  'uniformly': 966,
#  'excellent': 967,
#  'truth': 968,
#  'plain': 969,
#  'done': 970,
#  'rote': 971,
#  'introductory': 972,
#  'potions': 973,
#  'year': 974,
#  'capturing': 975,
#  'particular': 976,
#  'age': 977,
#  'group': 978,
#  'those': 979,
#  'late': 980,
#  '20s': 981,
#  'early': 982,
#  '30s': 983,
#  'entering': 984,
#  'adulthood': 985,
#  'certain': 986,
#  'reluctance': 987,
#  'trepidation': 988,
#  'ballards': 989,
#  'exist': 990,
#  'distract': 991,
#  'conventional': 992,
#  'failings': 993,
#  'craftsmanship': 994,
#  'bring': 995,
#  'spouse': 996,
#  'vicariously': 997,
#  'hickenlooper': 998,
#  'unsure': 999,
#  ...}

# %% [markdown]
# # Probability

# %%
num_fresh_data = train_data.Freshness.value_counts()["fresh"]
num_rotten_data = train_data.Freshness.value_counts()["rotten"]

# %% [markdown]
# ##### Calculating probability of wach word

# %%
all_probability = {}

for i in word_count:
    prob = word_count[i]/len(train_data)
    all_probability[i] = prob

# %%
fresh_probability = num_fresh_data/len(train_data)
rotten_probability = num_rotten_data/len(train_data)

# %%
all_probability
# Out:
# {'manakamana': 1.388888888888889e-05,
#  'doesnt': 0.029291666666666667,
#  'answer': 0.0013819444444444445,
#  'any': 0.025451388888888888,
#  'questions': 0.003232638888888889,
#  'yet': 0.015996527777777776,
#  'makes': 0.02439236111111111,
#  'its': 0.26983680555555556,
#  'point': 0.00960763888888889,
#  'nepal': 1.0416666666666666e-05,
#  'like': 0.0732326388888889,
#  'rest': 0.0036006944444444446,
#  'of': 0.6430034722222222,
#  'our': 0.011840277777777778,
#  'planet': 0.0012847222222222223,
#  'picturesque': 0.00018402777777777778,
#  'far': 0.014479166666666666,
#  'from': 0.07544444444444444,
#  'peaceable': 1.0416666666666666e-05,
#  'kingdom': 0.0007673611111111111,
#  'wilfully': 7.638888888888889e-05,
#  'offensive': 0.0013125,
#  'powered': 0.00023958333333333332,
#  'by': 0.07953125,
#  'chestthumping': 2.777777777777778e-05,
#  'machismo': 0.00019444444444444443,
#  'good': 0.038322916666666665,
#  'clean': 0.0006493055555555555,
#  'fun': 0.021520833333333333,
#  'it': 0.26091319444444444,
#  'difficult': 0.0035833333333333333,
#  'to': 0.4720902777777778,
#  'imagine': 0.002673611111111111,
#  'material': 0.008986111111111111,
#  'more': 0.07926736111111111,
#  'wrong': 0.004819444444444445,
#  'for': 0.1675,
#  'spade': 8.680555555555556e-05,
#  'than': 0.06851388888888889,
#  'lost': 0.0062118055555555555,
#  'found': 0.0048402777777777775,
#  'despite': 0.01259375,
#  'gusto': 0.00038194444444444446,
#  'star': 0.008576388888888889,
#  'brings': 0.003576388888888889,
#  'role': 0.005659722222222222,
#  'hard': 0.013236111111111112,
#  'ride': 0.004486111111111111,
#  'shotgun': 0.00018055555555555555,
#  'on': 0.10916666666666666,
#  'hectors': 2.0833333333333333e-05,
#  'voyage': 0.0002743055555555556,
#  'discovery': 0.0006145833333333333,
#  'if': 0.05776041666666667,
#  'there': 0.03343402777777778,
#  'idea': 0.006430555555555556,
#  'at': 0.08203125,
#  'core': 0.002375,
#  'this': 0.17007986111111112,
#  'havent': 0.001767361111111111,
#  'worked': 0.0016805555555555556,
#  'much': 0.04591666666666667,
#  'between': 0.017434027777777777,
#  'sequels': 0.0016423611111111111,
#  'simply': 0.007572916666666667,
#  'arent': 0.003767361111111111,
#  'special': 0.006861111111111111,
#  'even': 0.042875,
#  'that': 0.26090277777777776,
#  'theyre': 0.005076388888888889,
#  'free': 0.0020069444444444444,
#  'birds': 0.0005659722222222223,
#  'unappealingly': 2.0833333333333333e-05,
#  'staged': 0.0007777777777777777,
#  'paced': 0.0013402777777777777,
#  'uneven': 0.0028854166666666668,
#  'sluggishness': 1.736111111111111e-05,
#  'begs': 0.0003159722222222222,
#  'question': 0.0030694444444444445,
#  'since': 0.006628472222222222,
#  'things': 0.010888888888888889,
#  'always': 0.008256944444444445,
#  'seem': 0.007638888888888889,
#  'happening': 0.0010381944444444445,
#  'so': 0.061038194444444444,
#  'crushingly': 0.00018402777777777778,
#  'dull': 0.006361111111111111,
#  'joyless': 0.000625,
#  'misanthropic': 0.00021527777777777778,
#  '105': 0.00010416666666666667,
#  'minutes': 0.011190972222222222,
#  'worth': 0.00965625,
#  'comedy': 0.0326875,
#  'rates': 0.00010416666666666667,
#  'coen': 0.0010104166666666666,
#  'brothers': 0.0030208333333333333,
#  'their': 0.03319097222222222,
#  'worst': 0.006423611111111111,
#  'how': 0.025527777777777778,
#  'take': 0.013774305555555555,
#  'such': 0.015302083333333332,
#  'marvelous': 0.0006388888888888889,
#  'into': 0.04734027777777778,
#  'imponderable': 1.388888888888889e-05,
#  'mystery': 0.0038055555555555555,
#  'critic': 0.0005625,
#  'directed': 0.004993055555555555,
#  'john': 0.005413194444444444,
#  'glen': 8.333333333333333e-05,
#  'follows': 0.001517361111111111,
#  'numbers': 0.0010381944444444445,
#  'plodding': 0.0009270833333333334,
#  'unimaginative': 0.0005833333333333334,
#  'set': 0.008805555555555556,
#  'piece': 0.009368055555555555,
#  'next': 0.005541666666666667,
#  'purely': 0.0006736111111111112,
#  'visceral': 0.0014618055555555556,
#  'generating': 0.00025,
#  'adrenaline': 0.0006354166666666666,
#  'alarm': 8.680555555555556e-05,
#  'tears': 0.0016284722222222221,
#  'berg': 0.00036805555555555555,
#  'manages': 0.006104166666666667,
#  'avoid': 0.0013506944444444445,
#  'highminded': 0.00022222222222222223,
#  'seriousness': 0.0005243055555555555,
#  'while': 0.028743055555555556,
#  'still': 0.020701388888888887,
#  'respecting': 6.597222222222222e-05,
#  'peppermint': 0.00010069444444444445,
#  'least': 0.010121527777777778,
#  'trash': 0.0010069444444444444,
#  'decides': 0.0003784722222222222,
#  'awkwardlypaced': 3.4722222222222224e-06,
#  'exercise': 0.003930555555555555,
#  'shallowness': 9.722222222222222e-05,
#  'want': 0.009788194444444445,
#  'high': 0.007736111111111111,
#  'body': 0.0024861111111111112,
#  'count': 0.0011875,
#  'step': 0.0027395833333333335,
#  'right': 0.01338888888888889,
#  'brains': 0.0007013888888888889,
#  'behind': 0.0049791666666666665,
#  'brawns': 3.4722222222222224e-06,
#  'breaking': 0.0009131944444444444,
#  'wind': 0.0010347222222222222,
#  'vomiting': 9.722222222222222e-05,
#  'producing': 0.00028819444444444444,
#  'various': 0.0014027777777777777,
#  'gastric': 6.944444444444445e-06,
#  'noises': 0.00017708333333333335,
#  'etc': 0.0011284722222222221,
#  'own': 0.018322916666666668,
#  'enough': 0.027697916666666666,
#  'said': 0.003215277777777778,
#  'sweet': 0.005427083333333333,
#  'charming': 0.004701388888888889,
#  'theres': 0.02575,
#  'loss': 0.0015868055555555555,
#  'beloved': 0.0010590277777777779,
#  'leading': 0.00215625,
#  'man': 0.014010416666666666,
#  'lends': 0.00045138888888888887,
#  'picture': 0.009708333333333333,
#  'extra': 0.0009479166666666667,
#  'unexpected': 0.0022395833333333334,
#  'pathos': 0.0008819444444444444,
#  'perhaps': 0.006621527777777777,
#  'adequate': 0.0005208333333333333,
#  'animated': 0.00515625,
#  'children': 0.004152777777777778,
#  'thor': 0.0006180555555555555,
#  'odin': 1.0416666666666666e-05,
#  'others': 0.0033159722222222223,
#  'played': 0.0031631944444444446,
#  'piglets': 3.125e-05,
#  'arena': 0.00014583333333333335,
#  'comic': 0.007496527777777778,
#  'book': 0.006694444444444445,
#  'superheroes': 0.0005277777777777777,
#  'desolate': 0.00011805555555555556,
#  'vastation': 6.944444444444445e-06,
#  'short': 0.0065381944444444446,
#  'fresh': 0.0045451388888888885,
#  'ideas': 0.005913194444444445,
#  'thanks': 0.00403125,
#  'strong': 0.008246527777777778,
#  'performances': 0.017006944444444446,
#  'script': 0.014861111111111111,
#  'provides': 0.0027569444444444442,
#  'depth': 0.0032534722222222223,
#  'render': 0.0003368055555555556,
#  'characters': 0.0304375,
#  'collection': 0.001329861111111111,
#  'eccentricities': 0.00016319444444444443,
#  'thought': 0.004059027777777778,
#  'oscarwinning': 0.0004375,
#  '2004': 0.0003159722222222222,
#  'drama': 0.020864583333333332,
#  'crash': 0.0007256944444444444,
#  'heavyhanded': 0.0011979166666666666,
#  'wait': 0.0019270833333333334,
#  'until': 0.004680555555555556,
#  'crossing': 0.00028125,
#  'gatlifs': 2.0833333333333333e-05,
#  'view': 0.0026805555555555554,
#  'flamenco': 4.861111111111111e-05,
#  'excruciatingly': 0.0003125,
#  'trite': 0.0010555555555555555,
#  'mountain': 0.0008541666666666667,
#  'crap': 0.0006979166666666667,
#  'when': 0.031760416666666666,
#  'remembers': 0.00016319444444444443,
#  'supposed': 0.0022708333333333335,
#  'hokum': 0.0005520833333333334,
#  'wit': 0.003659722222222222,
#  'leave': 0.005621527777777777,
#  'attenborough': 3.8194444444444444e-05,
#  'wilson': 0.0010034722222222222,
#  'forget': 0.0024895833333333332,
#  'rash': 8.333333333333333e-05,
#  'putative': 3.8194444444444444e-05,
#  'improvements': 5.208333333333334e-05,
#  'wellscrubbed': 1.388888888888889e-05,
#  'family': 0.011402777777777777,
#  'fare': 0.001954861111111111,
#  'sex': 0.00496875,
#  'scenes': 0.011079861111111112,
#  'pretty': 0.009694444444444445,
#  'hot': 0.002111111111111111,
#  'though': 0.01610763888888889,
#  'diminished': 0.0002534722222222222,
#  'limited': 0.0011284722222222221,
#  'perfectly': 0.0034895833333333333,
#  'enjoyable': 0.006163194444444444,
#  'forgettable': 0.003125,
#  'general': 0.0017638888888888888,
#  'playful': 0.0011458333333333333,
#  'tone': 0.00590625,
#  'helps': 0.0010694444444444445,
#  'deal': 0.0021354166666666665,
#  'cinematography': 0.0023368055555555555,
#  'editing': 0.0018680555555555555,
#  'appealingly': 0.000125,
#  'glossy': 0.0010277777777777778,
#  'smooth': 0.0005451388888888888,
#  'spielbergs': 0.0006458333333333333,
#  'neither': 0.004451388888888889,
#  'purehearted': 1.388888888888889e-05,
#  'popcorn': 0.0018715277777777777,
#  'flick': 0.0059722222222222225,
#  'nor': 0.004597222222222222,
#  'paul': 0.0027604166666666667,
#  'verhoevenesque': 6.944444444444445e-06,
#  'subversion': 0.00015972222222222223,
#  'uneasily': 0.00012152777777777777,
#  'cowed': 1.388888888888889e-05,
#  'fanboy': 0.00026388888888888886,
#  'demographic': 0.0005138888888888889,
#  'political': 0.005486111111111111,
#  'pelting': 1.0416666666666666e-05,
#  'gripping': 0.0027083333333333334,
#  'focuses': 0.0007013888888888889,
#  'innocent': 0.0007118055555555556,
#  'whose': 0.006354166666666667,
#  'lives': 0.005201388888888889,
#  'destroyed': 0.0002465277777777778,
#  'either': 0.005642361111111111,
#  'terrorists': 0.00017361111111111112,
#  'administration': 0.00010069444444444445,
#  'feeling': 0.00659375,
#  'kempthompson': 6.944444444444445e-06,
#  'saw': 0.002125,
#  'bottom': 0.0008541666666666667,
#  'dirty': 0.001107638888888889,
#  'glass': 0.0010277777777777778,
#  'experience': 0.008902777777777779,
#  'precision': 0.0006354166666666666,
#  'duplicates': 1.736111111111111e-05,
#  'sensation': 0.0005590277777777778,
#  'success': 0.002736111111111111,
#  'reconstituted': 2.0833333333333333e-05,
#  'blend': 0.0015555555555555555,
#  'ghostbusters': 0.000375,
#  'meets': 0.0015520833333333333,
#  'men': 0.005690972222222222,
#  'pinch': 9.375e-05,
#  'xfiles': 0.00014930555555555555,
#  'problems': 0.0025555555555555557,
#  'dont': 0.017222222222222222,
#  'amount': 0.0024930555555555556,
#  'hill': 0.0009375,
#  'beans': 0.0001388888888888889,
#  'stalins': 2.4305555555555554e-05,
#  'ussr': 1.388888888888889e-05,
#  'real': 0.015697916666666666,
#  'experiencing': 0.00023611111111111112,
#  'them': 0.01973263888888889,
#  'world': 0.016527777777777777,
#  'doublethink': 3.4722222222222224e-06,
#  'cash': 0.0007673611111111111,
#  'grab': 0.0006770833333333334,
#  'painting': 0.00047916666666666664,
#  'perpetrator': 1.736111111111111e-05,
#  'saviour': 4.1666666666666665e-05,
#  'exploited': 0.00019791666666666666,
#  'victims': 0.0007361111111111111,
#  'fringes': 7.291666666666667e-05,
#  'society': 0.0018854166666666668,
#  'models': 0.0003368055555555556,
#  'figures': 0.0010694444444444445,
#  'inspiration': 0.0013055555555555555,
#  'mainstream': 0.0014965277777777778,
#  'uncritical': 0.00011111111111111112,
#  'audiences': 0.00684375,
#  'dogged': 0.00021875,
#  'insistence': 0.0002777777777777778,
#  'turning': 0.0018645833333333333,
#  'another': 0.01578125,
#  'seemingly': 0.0018368055555555555,
#  'endless': 0.001798611111111111,
#  'middlebrow': 0.0002708333333333333,
#  'meditations': 3.8194444444444444e-05,
#  'travails': 0.00011458333333333333,
#  'middleclass': 0.0002326388888888889,
#  'krampus': 4.1666666666666665e-05,
#  'toothless': 0.0004583333333333333,
#  'several': 0.0026944444444444446,
#  'levels': 0.0014097222222222221,
#  'very': 0.0264375,
#  'wellworn': 0.00044791666666666667,
#  'clichï½ï½s': 0.0022395833333333334,
#  'sf': 7.638888888888889e-05,
#  'completely': 0.005166666666666667,
#  'transparent': 0.00028125,
#  'production': 0.005065972222222223,
#  'design': 0.0025243055555555557,
#  'famil': 1.388888888888889e-05,
#  'beautifullymade': 1.388888888888889e-05,
#  'seriousminded': 9.027777777777777e-05,
#  'celebration': 0.001298611111111111,
#  'youll': 0.007302083333333333,
#  'hear': 0.0015416666666666667,
#  'phrase': 0.00040972222222222224,
#  'doors': 0.0002708333333333333,
#  'again': 0.008715277777777778,
#  'clear': 0.0037951388888888887,
#  'guys': 0.002340277777777778,
#  'making': 0.009725694444444445,
#  'translates': 0.00022222222222222223,
#  'onto': 0.0011909722222222222,
#  'marketed': 0.000125,
#  'historical': 0.0025833333333333333,
#  'fiction': 0.002715277777777778,
#  'king': 0.0023229166666666667,
#  'arthur': 0.0007152777777777778,
#  'actually': 0.007770833333333334,
#  'octane': 4.861111111111111e-05,
#  'fantasy': 0.005055555555555555,
#  'showcases': 0.0005034722222222222,
#  'excalibur': 3.472222222222222e-05,
#  'guiding': 0.00016666666666666666,
#  'destiny': 0.00028125,
#  'chemistry': 0.0031631944444444446,
#  'leads': 0.003777777777777778,
#  'breezy': 0.0010138888888888888,
#  'hourandtenminutes': 3.4722222222222224e-06,
#  'aging': 0.00047222222222222224,
#  'wistful': 0.00036458333333333335,
#  'reminiscences': 4.513888888888889e-05,
#  'itself': 0.0119375,
#  'lifetimes': 5.555555555555556e-05,
#  'pleasures': 0.0015555555555555555,
#  'operate': 0.00010416666666666667,
#  'genius': 0.0017708333333333332,
#  'level': 0.005395833333333333,
#  'given': 0.0054444444444444445,
#  'field': 0.0009270833333333334,
#  'mean': 0.0030868055555555557,
#  'cost': 0.00059375,
#  'purgatory': 0.00015277777777777777,
#  'bobby': 0.0003368055555555556,
#  'fischer': 0.00014236111111111112,
#  'inhabited': 6.25e-05,
#  'essential': 0.0016319444444444445,
#  'maintaining': 0.0002708333333333333,
#  'powerful': 0.005927083333333334,
#  'atmospherics': 0.0001388888888888889,
#  'superb': 0.002201388888888889,
#  'cast': 0.016385416666666666,
#  'includes': 0.0008888888888888889,
#  'nicole': 0.00041319444444444444,
#  'kidman': 0.000625,
#  ...}

# %% [markdown]
# ##### Calculating conditional probability of each word for fresh and rotten

# %%
fresh_words_conditional={x: 0 for x in words}
rotten_words_conditional={x: 0 for x in words}
for i,j in tqdm(train_data.iterrows(),total = len(train_data)):
    for k in j["Review"].split():
        if k in words:
            if j["Freshness"] == "fresh":
                fresh_words_conditional[k] += 1
            else:
                rotten_words_conditional[k] += 1
# Out:
# 100%|█████████████████████████████████| 288000/288000 [02:31<00:00, 1904.88it/s]

# %%
fresh_probability_words = {}
rotten_probability_words = {}
for i in fresh_words_conditional:
    prob = fresh_words_conditional[i]/num_fresh_data
    fresh_probability_words[i] = prob

for i in rotten_words_conditional:
    prob = rotten_words_conditional[i]/num_rotten_data
    rotten_probability_words[i] = prob

# %%
for i in range(10):
    word = words[i]
    print(f"\tP({word}|fresh):", fresh_probability_words[word])
    print(f"\tP({word}|rotten):", rotten_probability_words[word])
# Out:
# 	P(doesnt|fresh): 0.021634031809448503
# 	P(doesnt|rotten): 0.03696751002927087
# 	P(answer|fresh): 0.0012415811779067911
# 	P(answer|rotten): 0.0015226414700790522
# 	P(any|fresh): 0.019310402230684396
# 	P(any|rotten): 0.03160697773049941
# 	P(questions|fresh): 0.004078490126308342
# 	P(questions|rotten): 0.00238477636637952
# 	P(yet|fresh): 0.018380950399178753
# 	P(yet|rotten): 0.013606435419838836
# 	P(makes|fresh): 0.02888930506135076
# 	P(makes|rotten): 0.019884724221123695
# 	P(its|fresh): 0.27544374388746695
# 	P(its|rotten): 0.26421653491298697
# 	P(point|fresh): 0.006721185259171401
# 	P(point|rotten): 0.012500955996356785
# 	P(like|fresh): 0.06001900520909198
# 	P(like|rotten): 0.08647769225955823
# 	P(rest|fresh): 0.0025525244327916155
# 	P(rest|rotten): 0.004651356819556557

# %% [markdown]
# # Smoothing

# %% [markdown]
# ### Adding Lidstone smoothing to the word counts

# %%
gama=1
smooth_fresh_words = {}
smooth_rotten_words={}
for i in fresh_words_conditional:
    smooth = (fresh_words_conditional[i]+gama)/(num_fresh_data + gama * len(words))
    smooth_fresh_words[i] = smooth

for i in rotten_words_conditional:
    smooth = (rotten_words_conditional[i]+gama)/(num_rotten_data + gama * len(words))
    smooth_rotten_words[i] = smooth

# %%
for i in range(10):
    word = words[i]
    print(f"\tP({word}|fresh):", smooth_fresh_words[word])
    print(f"\tP({word}|rotten):", smooth_rotten_words[word])
# Out:
# 	P(doesnt|fresh): 0.017296242502189748
# 	P(doesnt|rotten): 0.029537224234076113
# 	P(answer|fresh): 0.0009978601443571009
# 	P(answer|rotten): 0.0012219235298038258
# 	P(any|fresh): 0.01543911390019181
# 	P(any|rotten): 0.02525493768189998
# 	P(questions|fresh): 0.00326522013903518
# 	P(questions|rotten): 0.001910644064784164
# 	P(yet|fresh): 0.014696262459392637
# 	P(yet|rotten): 0.010875119415254049
# 	P(makes|fresh): 0.023094918674398234
# 	P(makes|rotten): 0.01589056008531248
# 	P(its|fresh): 0.22015012251505106
# 	P(its|rotten): 0.21107618137788542
# 	P(point|fresh): 0.005377357444591044
# 	P(point|rotten): 0.009992001955077648
# 	P(like|fresh): 0.04797489827370195
# 	P(like|rotten): 0.06908866721468085
# 	P(rest|fresh): 0.002045613295932057
# 	P(rest|rotten): 0.0037213125680389237

# %% [markdown]
# # Dev Data

# %% [markdown]
# #### Predicting class for Development data without smoothing

# %%
prediction = []

for sentence in validation_data["Review"]:
    new_fresh_prob = fresh_probability
    new_rotten_prob = rotten_probability
    for word in sentence.split():
        if word in word_to_index:
            index = word_to_index[word]
            new_fresh_prob*= fresh_probability_words[word]
            new_rotten_prob*=rotten_probability_words[word]
    if new_fresh_prob>new_rotten_prob:
        prediction.append("fresh")
    else:
        prediction.append("rotten")

# %%
accuracy = sum(prediction == validation_data.Freshness)/len(validation_data)
print(f"Accuracy without smoothing = {accuracy}")
# Out:
# Accuracy without smoothing = 0.7934375

# %% [markdown]
# #### Predicting class for Development data with smoothing

# %%
prediction_smooth = []

for sentence in validation_data["Review"]:
    new_fresh_prob = fresh_probability+len(fresh_words_conditional)
    new_rotten_prob = rotten_probability+len(rotten_words_conditional)
    for word in sentence.split():
        if word in word_to_index:
            index = word_to_index[word]
            new_fresh_prob*= (fresh_words_conditional[word]+1)/(num_fresh_data+len(fresh_words_conditional))
            new_rotten_prob*=(rotten_words_conditional[word]+1)/(num_rotten_data+len(fresh_words_conditional))
    if new_fresh_prob>new_rotten_prob:
        prediction_smooth.append("fresh")
    else:
        prediction_smooth.append("rotten")

# %%
accuracy = sum(prediction_smooth == validation_data.Freshness)/len(validation_data)
print(f"Accuracy With smoothing = {accuracy}")
# Out:
# Accuracy With smoothing = 0.7950416666666666

# %%
print("We can observe from above that after smoothing the accuracy of development data increased slightly")
# Out:
# We can observe from above that after smoothing the accuracy of development data increased slightly

# %% [markdown]
# # Top 10 Words

# %%
fresh_words = {x:0 for x in words}
probs = np.array(list(smooth_fresh_words.values()))/np.array(list(smooth_rotten_words.values()))
for i,j in enumerate(fresh_words):
    fresh_words[j] = probs[i]
rotten_words = {x:0 for x in words}
probs = np.array(list(smooth_rotten_words.values()))/np.array(list(smooth_fresh_words.values()))
for i,j in enumerate(fresh_words):
    rotten_words[j] = probs[i]

# %%
fresh_top_10  = sorted(fresh_words, key=lambda x: fresh_words[x],reverse=True)[:10]
rotten_top_10 = sorted(rotten_words, key=lambda x: rotten_words[x],reverse=True)[:10]

# %%
print(f"Top 10 Fresh Words {fresh_top_10}\n\n\nTop 10 Rotten words{rotten_top_10}")
# Out:
# Top 10 Fresh Words ['spiderverse', 'unmissable', 'nimbly', 'ida', 'unadorned', 'koreedas', 'tonic', 'captivates', 'cannily', 'langs']
#
#
# Top 10 Rotten words['charmless', 'mirthless', 'squanders', 'flavorless', 'unexciting', 'feeble', 'lifeless', 'thirdrate', 'unfunny', 'drearily']

# %%
for i in fresh_top_10:
    if i in words:
        print(f"Probability[Fresh|{i}] = {smooth_fresh_words[i]/(smooth_fresh_words[i]+smooth_rotten_words[i])}")
        print(f"Probability[Rotten|{i}] = {smooth_rotten_words[i]/(smooth_fresh_words[i]+smooth_rotten_words[i])}")
        print("\n")
# Out:
# Probability[Fresh|spiderverse] = 0.9755645580566952
# Probability[Rotten|spiderverse] = 0.024435441943304832
#
#
# Probability[Fresh|unmissable] = 0.9736355406463651
# Probability[Rotten|unmissable] = 0.02636445935363476
#
#
# Probability[Fresh|nimbly] = 0.9729230242705986
# Probability[Rotten|nimbly] = 0.027076975729401365
#
#
# Probability[Fresh|ida] = 0.9713758524834327
# Probability[Rotten|ida] = 0.02862414751656727
#
#
# Probability[Fresh|unadorned] = 0.9676826403970399
# Probability[Rotten|unadorned] = 0.0323173596029601
#
#
# Probability[Fresh|koreedas] = 0.9666054632814863
# Probability[Rotten|koreedas] = 0.033394536718513675
#
#
# Probability[Fresh|tonic] = 0.9666054632814863
# Probability[Rotten|tonic] = 0.033394536718513675
#
#
# Probability[Fresh|captivates] = 0.9666054632814863
# Probability[Rotten|captivates] = 0.033394536718513675
#
#
# Probability[Fresh|cannily] = 0.9654540029546397
# Probability[Rotten|cannily] = 0.034545997045360266
#
#
# Probability[Fresh|langs] = 0.9654540029546397
# Probability[Rotten|langs] = 0.034545997045360266

# %%
for i in rotten_top_10:
    if i in words:
        print(f"Probability[Rotten|{i}] = {smooth_rotten_words[i]/(smooth_fresh_words[i]+smooth_rotten_words[i])}")
        print(f"Probability[Fresh|{i}] = {smooth_fresh_words[i]/(smooth_fresh_words[i]+smooth_rotten_words[i])}")
        print("\n")
# Out:
# Probability[Rotten|charmless] = 0.9930201587479303
# Probability[Fresh|charmless] = 0.006979841252069793
#
#
# Probability[Rotten|mirthless] = 0.9824888198987324
# Probability[Fresh|mirthless] = 0.017511180101267693
#
#
# Probability[Rotten|squanders] = 0.9784184868571637
# Probability[Fresh|squanders] = 0.02158151314283632
#
#
# Probability[Rotten|flavorless] = 0.9778189751224217
# Probability[Fresh|flavorless] = 0.022181024877578344
#
#
# Probability[Rotten|unexciting] = 0.9750462155884785
# Probability[Fresh|unexciting] = 0.024953784411521508
#
#
# Probability[Rotten|feeble] = 0.9741856980703746
# Probability[Fresh|feeble] = 0.025814301929625427
#
#
# Probability[Rotten|lifeless] = 0.9719268262013655
# Probability[Fresh|lifeless] = 0.028073173798634457
#
#
# Probability[Rotten|thirdrate] = 0.9714811961284731
# Probability[Fresh|thirdrate] = 0.028518803871526943
#
#
# Probability[Rotten|unfunny] = 0.971234622392189
# Probability[Fresh|unfunny] = 0.028765377607810973
#
#
# Probability[Rotten|drearily] = 0.9706423610035381
# Probability[Fresh|drearily] = 0.029357638996461963

# %% [markdown]
# # Test Data

# %%
prediction_smooth_test = []

for sentence in test_data["Review"]:
    new_fresh_prob = fresh_probability+len(fresh_words_conditional)
    new_rotten_prob = rotten_probability+len(rotten_words_conditional)
    for word in sentence.split():
        if word in word_to_index:
            index = word_to_index[word]
            new_fresh_prob*= (fresh_words_conditional[word]+1)/(num_fresh_data+len(fresh_words_conditional))
            new_rotten_prob*=(rotten_words_conditional[word]+1)/(num_rotten_data+len(fresh_words_conditional))
    if new_fresh_prob>new_rotten_prob:
        prediction_smooth_test.append("fresh")
    else:
        prediction_smooth_test.append("rotten")

# %%
accuracy = sum(prediction_smooth_test == test_data.Freshness)/len(test_data)
print(f"Accuracy of Testing data with optimal parameters is {accuracy}")
# Out:
# Accuracy of Testing data with optimal parameters is 0.7960208333333333
